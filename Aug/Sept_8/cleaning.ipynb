# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Junayed\pandas_prac\Aug\Sept_8\messy_library_day15.csv")

# %%
df.shape
# Out:
# (48, 14)

# %%
df.dtypes
# Out:
# LoanID              str
# PatronName          str
# PatronEmail         str
# Branch              str
# BookTitle           str
# Genre               str
# FormatType          str
# CheckoutDate        str
# DueDate             str
# ReturnDate          str
# RenewalCount    float64
# FineAmount      float64
# LoanStatus          str
# Notes               str
# dtype: object

# %%
df.head(5)
# Out:
#   LoanID        PatronName                PatronEmail              Branch  \
# 0   L001  Wendell Ashcroft  wendell.ashcroft@mail.com  Main Street Branch
# 1   L002    keisha johnson    keisha.johnson@mail.com     westside branch
# 2   L003      Farid Nasser     farid.nasser@@mail.com     Downtown Branch
# 3   L004       Odalys Rein       odalys.rein@mail.com    riverside branch
# 4   L005   MARCUS OYELARAN   marcus.oyelaran@mail.com  MAIN STREET BRANCH
#
#                    BookTitle     Genre FormatType CheckoutDate      DueDate  \
# 0         The Silent Orchard   Fiction       Book   2024-05-01   2024-05-22
# 1  Murder at Wrenfield House   Mystery       book   05/02/2024   05/23/2024
# 2       Beyond the Ion Storm    sci-fi  audiobook  03-May-2024   05/10/2024
# 3            A Life in Ashes  biograpy        DVD   05/04/2024  11-May-2024
# 4           Hearts in Autumn   romance        DVD   2024-05-05   2024-05-12
#
#     ReturnDate  RenewalCount  FineAmount LoanStatus Notes
# ...

# %%
df["PatronEmail"] = df["PatronEmail"].str.strip().str.title()

# %%
df["PatronEmail"].values
# Out:
# <ArrowStringArray>
# [    'Wendell.Ashcroft@Mail.Com',       'Keisha.Johnson@Mail.Com',
#         'Farid.Nasser@@Mail.Com',          'Odalys.Rein@Mail.Com',
#       'Marcus.Oyelaran@Mail.Com',           'Priscilla.Tran@Mail',
#           'Bennett.Cho@Mail.Com',                             nan,
#        'Hugo.Delacroix@Mail.Com',     'Selene.Marchetti@Mail.Com',
#          'Otis.Renwick@Mail.Com',          'Aisha.Bello@Mail.Com',
#    'Callum.Fairweather@Mail.Com',        'Nadia.Vukovic@Mail.Com',
#       'Reuben.Halloway@Mail.Com',         'Tamsin.Okoro@Mail.Com',
#         'Julio.Peralta@Mail.Com',                             nan,
#        'Desmond.Achebe@Mail.Com',     'Marguerite.Solis@Mail.Com',
#       'Cyrus.Abernathy@Mail.Com', 'Priya.Chandrasekaran@Mail.Com',
#          'Otis.Renwick@Mail.Com',       'Beatrix.Solano@Mail.Com',
#      'Wendell.Ashcroft@Mail.Com',       'Keisha.Johnson@Mail.Com',
#         'Farid.Nasser@@Mail.Com',          'Odalys.Rein@Mail.Com',
# ...
