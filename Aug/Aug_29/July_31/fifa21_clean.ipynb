# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Junayed\pandas_prac\July_31\fifa21_raw_data.csv')
# Out:
# C:\Users\Junayed\AppData\Local\Temp\ipykernel_2144\1445634077.py:1: DtypeWarning: Columns (0: Hits) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\Junayed\pandas_prac\July_31\fifa21_raw_data.csv')

# %%
df.head(10)
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
# 5  https://cdn.sofifa.com/players/188/545/21_60.png
# 6  https://cdn.sofifa.com/players/231/747/21_60.png
# 7  https://cdn.sofifa.com/players/212/831/21_60.png
# 8  https://cdn.sofifa.com/players/209/331/21_60.png
# 9  https://cdn.sofifa.com/players/208/722/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
# 5            Robert Lewandowski
# 6                 Kylian Mbappé
# 7         Alisson Ramses Becker
# 8                 Mohamed Salah
# 9                    Sadio Mané
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   photoUrl          18979 non-null  str
#  1   LongName          18979 non-null  str
#  2   playerUrl         18979 non-null  str
#  3   Nationality       18979 non-null  str
#  4   Positions         18979 non-null  str
#  5   Name              18979 non-null  str
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Team & Contract   18979 non-null  str
#  10  ID                18979 non-null  int64
#  11  Height            18979 non-null  str
#  12  Weight            18979 non-null  str
#  13  foot              18979 non-null  str
#  14  BOV               18979 non-null  int64
#  15  BP                18979 non-null  str
#  16  Growth            18979 non-null  int64
# ...

# %%
df.dtypes
# Out:
# photoUrl          str
# LongName          str
# playerUrl         str
# Nationality       str
# Positions         str
#                 ...
# PAS             int64
# DRI             int64
# DEF             int64
# PHY             int64
# Hits           object
# Length: 77, dtype: object

# %%
df.isnull().sum()
# Out:
# photoUrl       0
# LongName       0
# playerUrl      0
# Nationality    0
# Positions      0
#               ..
# PAS            0
# DRI            0
# DEF            0
# PHY            0
# Hits           0
# Length: 77, dtype: int64

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...

# %%
df['foot'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18974    Right
# 18975    Right
# 18976    Right
# 18977    Right
# 18978    Right
# Name: foot, Length: 18979, dtype: str>

# %%
df['Joined'] = pd.to_datetime(df['Joined']).dt.strftime("%d-%m-%Y")

# %%
df['Wage'].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df['W/F'] = df['W/F'].str.strip("★")

# %%
df['IR'] = df['IR'].str.strip("★")

# %%
df.to_excel("fifacleaned.xlsx", index=False)
